# %% [markdown]
# <h1 align='center'><font color='brown'> Pandas Task

# %% [markdown]
# ##  <a href='https://www.kaggle.com/toramky/automobile-dataset'> **Dataset**</a>
#
# ## **Content**
# This data set consists of three types of entities: (a) the specification of an auto in terms of various characteristics, (b) its assigned insurance risk rating, (c) its normalized losses in use as compared to other cars. The second rating corresponds to the degree to which the auto is more risky than its price indicates. Cars are initially assigned a risk factor symbol associated with its price. Then, if it is more risky (or less), this symbol is adjusted by moving it up (or down) the scale. Actuarians call this process "symboling". A value of +3 indicates that the auto is risky, -3 that it is probably pretty safe.
#
# The third factor is the relative average loss payment per insured vehicle year. This value is normalized for all autos within a particular size classification (two-door small, station wagons, sports/speciality, etc…), and represents the average loss per car per year.
#
# Note: Several of the attributes in the database could be used as a "class" attribute.

# %% [markdown]
# ### import pandas

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

#set seaborn plotting aesthetics as default
sns.set()

# %% [markdown]
# ### import data

# %% [markdown]
# >**note**: if all columns don't appear, make them appear

# %%
Automobile_data = pd.read_csv('Automobile_data.csv')
pd.set_option('display.max_columns', None)  #to display max columns in data frame
Automobile_data
# Out:
#      symboling normalized-losses         make fuel-type aspiration  \
# 0            3                 ?  alfa-romero       gas        std
# 1            3                 ?  alfa-romero       gas        std
# 2            1                 ?  alfa-romero       gas        std
# 3            2               164         audi       gas        std
# 4            2               164         audi       gas        std
# ..         ...               ...          ...       ...        ...
# 200         -1                95        volvo       gas        std
# 201         -1                95        volvo       gas      turbo
# 202         -1                95        volvo       gas        std
# 203         -1                95        volvo    diesel      turbo
# 204         -1                95        volvo       gas      turbo
#
#     num-of-doors   body-style drive-wheels engine-location  wheel-base  \
# 0            two  convertible          rwd           front        88.6
# ...

# %% [markdown]
# ### Show first 5 rows in data

# %%
Automobile_data.head()
# Out:
#    symboling normalized-losses         make fuel-type aspiration num-of-doors  \
# 0          3                 ?  alfa-romero       gas        std          two
# 1          3                 ?  alfa-romero       gas        std          two
# 2          1                 ?  alfa-romero       gas        std          two
# 3          2               164         audi       gas        std         four
# 4          2               164         audi       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 0  convertible          rwd           front        88.6   168.8   64.1
# 1  convertible          rwd           front        88.6   168.8   64.1
# 2    hatchback          rwd           front        94.5   171.2   65.5
# 3        sedan          fwd           front        99.8   176.6   66.2
# 4        sedan          4wd           front        99.4   176.6   66.4
#
# ...

# %% [markdown]
# ### Show last 5 rows in data

# %%
Automobile_data.tail()
# Out:
#      symboling normalized-losses   make fuel-type aspiration num-of-doors  \
# 200         -1                95  volvo       gas        std         four
# 201         -1                95  volvo       gas      turbo         four
# 202         -1                95  volvo       gas        std         four
# 203         -1                95  volvo    diesel      turbo         four
# 204         -1                95  volvo       gas      turbo         four
#
#     body-style drive-wheels engine-location  wheel-base  length  width  \
# 200      sedan          rwd           front       109.1   188.8   68.9
# 201      sedan          rwd           front       109.1   188.8   68.8
# 202      sedan          rwd           front       109.1   188.8   68.9
# 203      sedan          rwd           front       109.1   188.8   68.9
# 204      sedan          rwd           front       109.1   188.8   68.9
#
#      height  curb-weight engine-type num-of-cylinders  engine-size  \
# ...

# %% [markdown]
# ### Show information about data

# %%
#from info() function we notice that :
# 1- we have 205 rows and 26 columns
# 2- all columns don't have a missing values
# 3- we have some columns with wrong data types
# 4- we want reblace (-) to (_) in name of columns

Automobile_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized-losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel-type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num-of-doors       205 non-null    object
#  6   body-style         205 non-null    object
#  7   drive-wheels       205 non-null    object
#  8   engine-location    205 non-null    object
#  9   wheel-base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb-weight        205 non-null    int64
#  14  engine-type        205 non-null    object
#  15  num-of-cylinders   205 non-null    object
# ...

# %%
Automobile_data.describe()
# Out:
#         symboling  wheel-base      length       width      height  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#        curb-weight  engine-size  compression-ratio    city-mpg  highway-mpg
# count   205.000000   205.000000         205.000000  205.000000   205.000000
# mean   2555.565854   126.907317          10.142537   25.219512    30.751220
# std     520.680204    41.642693           3.972040    6.542142     6.886443
# ...

# %% [markdown]
# ## Now is cleeeeaning 🧹
# ______________________________________
# > **1- we have 205 rows and 26 columns**
#
# > **2- all columns don't have a missing values Until now, but there may be missing data of another type, which is that there are values that are not similar to the other values in the column**
#
# > **3- we have some columns with wrong data types**
#
# > **4- we want reblace ( - ) to ( _ ) in name of columns**

# %%
# remove all dash '-' from columns with replace to underscore '_' and convert all names of columns to lower case

Automobile_data.columns = Automobile_data.columns.str.replace('-','_').str.lower()
Automobile_data.columns
# Out:
# Index(['symboling', 'normalized_losses', 'make', 'fuel_type', 'aspiration',
#        'num_of_doors', 'body_style', 'drive_wheels', 'engine_location',
#        'wheel_base', 'length', 'width', 'height', 'curb_weight', 'engine_type',
#        'num_of_cylinders', 'engine_size', 'fuel_system', 'bore', 'stroke',
#        'compression_ratio', 'horsepower', 'peak_rpm', 'city_mpg',
#        'highway_mpg', 'price'],
#       dtype='object')

# %%
# We can notice here that we have a fixed range of numbers starting from 3 to -2, so we convert data type from int to category

print(Automobile_data['symboling'].value_counts())
print('\nThe sum of values: ' + str(Automobile_data['symboling'].value_counts().sum()))
# Out:
#  0    67
#  1    54
#  2    32
#  3    27
# -1    22
# -2     3
# Name: symboling, dtype: int64
#
# The sum of values: 205

# %%
Automobile_data['symboling'].astype('category')
# Out:
# 0      3
# 1      3
# 2      1
# 3      2
# 4      2
#       ..
# 200   -1
# 201   -1
# 202   -1
# 203   -1
# 204   -1
# Name: symboling, Length: 205, dtype: category
# Categories (6, int64): [-2, -1, 0, 1, 2, 3]

# %%
#function to get some information for all columns in dataframe as unique value, number of value and data type

def info_columns(dataframe): 
   
    for column in dataframe.columns:
        print('Name of columns: '+ column + '\n')
        print(dataframe[column].unique())
        print('\nThe sum of values: ' + str(dataframe[column].value_counts().sum()))
        print('and data type is: '+ str(dataframe[column].dtype))
        print('\n--------------------------------------\n')
        
        
# 1- We can notice here that we have some columns have a fixed range of numbers, so we convert data type to category
# 2- And we notice some data type invalid because the columns have a '?' that This is the main reason for converting 
# columns to object data type
# 3- we have some missing value but not explicitly the missing value represent as '?'


info_columns(Automobile_data)
# Out:
# Name of columns: symboling
#
# [3, 1, 2, 0, -1, -2]
# Categories (6, int64): [-2, -1, 0, 1, 2, 3]
#
# The sum of values: 205
# and data type is: category
#
# --------------------------------------
#
# Name of columns: normalized_losses
#
# [  0. 164. 158. 192. 188. 121.  98.  81. 118. 148. 110. 145. 137. 101.
#   78. 106.  85. 107. 104. 113. 150. 129. 115.  93. 142. 161. 153. 125.
#  128. 122. 103. 168. 108. 194. 231. 119. 154.  74. 186.  83. 102.  89.
#   87.  77.  91. 134.  65. 197.  90.  94. 256.  95.]
#
# The sum of values: 205
# and data type is: float64
#
# --------------------------------------
#
# Name of columns: make
#
# ['alfa-romero' 'audi' 'bmw' 'chevrolet' 'dodge' 'honda' 'isuzu' 'jaguar'
#  'mazda' 'mercedes-benz' 'mercury' 'mitsubishi' 'nissan' 'peugot'
#  'plymouth' 'porsche' 'renault' 'saab' 'subaru' 'toyota' 'volkswagen'
#  'volvo']
#
# The sum of values: 205
# and data type is: object
#
# --------------------------------------
#
# Name of columns: fuel_type
#
# ...

# %%
#Here two columns from columns that will convert data type to category the 'num_of_doors' have a missing value id '?' 
#repeated two times

print(Automobile_data['num_of_doors'].value_counts())
print('\n--------------------------------------\n')
Automobile_data['num_of_doors'] = Automobile_data['num_of_doors'].replace('?', 'not_found')

Automobile_data['num_of_doors'].unique()
# Out:
# four    114
# two      89
# ?         2
# Name: num_of_doors, dtype: int64
#
# --------------------------------------
# array(['two', 'four', 'not_found'], dtype=object)

# %%
#change data type of columns that which should be "category" data type

category_columns = ['symboling', 'fuel_type', 'aspiration', 'num_of_doors', 'body_style', 'drive_wheels', 'engine_location',
                    'engine_type', 'num_of_cylinders', 'fuel_system']

for column in category_columns:
    Automobile_data[column] = Automobile_data[column].astype('category')
    
Automobile_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    category
#  1   normalized_losses  205 non-null    object
#  2   make               205 non-null    object
#  3   fuel_type          205 non-null    category
#  4   aspiration         205 non-null    category
#  5   num_of_doors       205 non-null    category
#  6   body_style         205 non-null    category
#  7   drive_wheels       205 non-null    category
#  8   engine_location    205 non-null    category
#  9   wheel_base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb_weight        205 non-null    int64
#  14  engine_type        205 non-null    category
# ...

# %% [markdown]
# ## <font color='red'> Display The columns that have category values
# ____________________________________________________________________

# %%
fig, axes = plt.subplots(5, 2, figsize=(15,20))
sns.color_palette("viridis", as_cmap=True)

sns.countplot(data=Automobile_data, y=category_columns[0],palette= 'viridis', 
                          order= Automobile_data[category_columns[0]].value_counts().index[:], ax=axes[0,0])

sns.countplot(data=Automobile_data, y=category_columns[1],palette= 'viridis', 
                          order= Automobile_data[category_columns[1]].value_counts().index[:], ax=axes[0,1])

sns.countplot(data=Automobile_data, y=category_columns[2],palette= 'viridis', 
                          order= Automobile_data[category_columns[2]].value_counts().index[:], ax=axes[1,0])

sns.countplot(data=Automobile_data, y=category_columns[3],palette= 'viridis', 
                          order= Automobile_data[category_columns[3]].value_counts().index[:], ax=axes[1,1])

sns.countplot(data=Automobile_data, y=category_columns[4],palette= 'viridis', 
                          order= Automobile_data[category_columns[4]].value_counts().index[:], ax=axes[2,0])

sns.countplot(data=Automobile_data, y=category_columns[5],palette= 'viridis', 
                          order= Automobile_data[category_columns[5]].value_counts().index[:], ax=axes[2,1])

sns.countplot(data=Automobile_data, y=category_columns[6],palette= 'viridis', 
                          order= Automobile_data[category_columns[6]].value_counts().index[:], ax=axes[3,0])

sns.countplot(data=Automobile_data, y=category_columns[7],palette= 'viridis', 
                          order= Automobile_data[category_columns[7]].value_counts().index[:], ax=axes[3,1])

sns.countplot(data=Automobile_data, y=category_columns[8],palette= 'viridis', 
                          order= Automobile_data[category_columns[8]].value_counts().index[:], ax=axes[4,0])

sns.countplot(data=Automobile_data, y=category_columns[9],palette= 'viridis', 
                          order= Automobile_data[category_columns[9]].value_counts().index[:], ax=axes[4,1])
# Out:
# <AxesSubplot:xlabel='count', ylabel='fuel_system'>

# %% [markdown]
# ### Transform (normalized-losses, bore, stroke, horsepower, peak_rpm, price) from object to numeric

# %%
#change data type of columns that which should be "numeric" data type

numeric_columns = ['normalized_losses', 'bore', 'stroke', 'horsepower', 'peak_rpm', 'price']

for column in numeric_columns:
    Automobile_data[column] = pd.to_numeric(Automobile_data[column], errors= 'coerce')
    
Automobile_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    category
#  1   normalized_losses  164 non-null    float64
#  2   make               205 non-null    object
#  3   fuel_type          205 non-null    category
#  4   aspiration         205 non-null    category
#  5   num_of_doors       205 non-null    category
#  6   body_style         205 non-null    category
#  7   drive_wheels       205 non-null    category
#  8   engine_location    205 non-null    category
#  9   wheel_base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb_weight        205 non-null    int64
#  14  engine_type        205 non-null    category
# ...

# %% [markdown]
# ## <font color='red'> Display The columns that have numeric values
# ____________________________________________________________________

# %%
fig, axes = plt.subplots(3, 2, figsize=(15,20))

sns.histplot(data=Automobile_data, x="normalized_losses", kde=True,ax=axes[0,0])
sns.histplot(data=Automobile_data, x="bore", kde=True,ax=axes[0,1], color='red')
sns.histplot(data=Automobile_data, x="stroke", kde=True,ax=axes[1,0],color='orange')
sns.histplot(data=Automobile_data, x="horsepower", kde=True,ax=axes[1,1], color='green')
sns.histplot(data=Automobile_data, x="peak_rpm", kde=True,ax=axes[2,0], color='black')
sns.histplot(data=Automobile_data, x="price", kde=True,ax=axes[2,1], color='blue')
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %% [markdown]
# ### filter the data which has (body_style) sedan **and** (engine_type) is ohc

# %%
Automobile_data[(Automobile_data['body_style'] == 'sedan') & (Automobile_data['engine_type'] == 'ohc')].reset_index(drop=True)
# Out:
#    symboling  normalized_losses   make fuel_type aspiration num_of_doors  \
# 0          2              164.0   audi       gas        std         four
# 1          2              164.0   audi       gas        std         four
# 2          2                NaN   audi       gas        std          two
# 3          1              158.0   audi       gas        std         four
# 4          1              158.0   audi       gas      turbo         four
# ..       ...                ...    ...       ...        ...          ...
# 68        -2              103.0  volvo       gas      turbo         four
# 69        -1               95.0  volvo       gas        std         four
# 70        -1               95.0  volvo       gas      turbo         four
# 71        -1               95.0  volvo    diesel      turbo         four
# 72        -1               95.0  volvo       gas      turbo         four
#
#    body_style drive_wheels engine_location  wheel_base  length  width  height  \
# ...

# %% [markdown]
# ### Show data which (make) is bmw

# %%
Automobile_data[Automobile_data['make'].str.lower() == 'bmw'].reset_index(drop=True)
# Out:
#   symboling  normalized_losses make fuel_type aspiration num_of_doors  \
# 0         2              192.0  bmw       gas        std          two
# 1         0              192.0  bmw       gas        std         four
# 2         0              188.0  bmw       gas        std          two
# 3         0              188.0  bmw       gas        std         four
# 4         1                NaN  bmw       gas        std         four
# 5         0                NaN  bmw       gas        std         four
# 6         0                NaN  bmw       gas        std          two
# 7         0                NaN  bmw       gas        std         four
#
#   body_style drive_wheels engine_location  wheel_base  length  width  height  \
# 0      sedan          rwd           front       101.2   176.8   64.8    54.3
# 1      sedan          rwd           front       101.2   176.8   64.8    54.3
# 2      sedan          rwd           front       101.2   176.8   64.8    54.3
# ...

# %% [markdown]
# ### Show the shape of data

# %%
Automobile_data.shape
# Out:
# (205, 26)

# %% [markdown]
# ### Delete (price) column and show data without it

# %%
Automobile_data.drop('price', axis= 1)
# Out:
#     symboling  normalized_losses         make fuel_type aspiration  \
# 0           3                NaN  alfa-romero       gas        std
# 1           3                NaN  alfa-romero       gas        std
# 2           1                NaN  alfa-romero       gas        std
# 3           2              164.0         audi       gas        std
# 4           2              164.0         audi       gas        std
# ..        ...                ...          ...       ...        ...
# 200        -1               95.0        volvo       gas        std
# 201        -1               95.0        volvo       gas      turbo
# 202        -1               95.0        volvo       gas        std
# 203        -1               95.0        volvo    diesel      turbo
# 204        -1               95.0        volvo       gas      turbo
#
#     num_of_doors   body_style drive_wheels engine_location  wheel_base  \
# 0            two  convertible          rwd           front        88.6
# ...

# %% [markdown]
# ### Show more details about (body style)

# %%
Automobile_data['body_style'].describe()
# Out:
# count       205
# unique        5
# top       sedan
# freq         96
# Name: body_style, dtype: object

# %% [markdown]
# ### Show count of missing values in each column

# %%
Automobile_data.isnull().sum()
# Out:
# symboling             0
# normalized_losses    41
# make                  0
# fuel_type             0
# aspiration            0
# num_of_doors          0
# body_style            0
# drive_wheels          0
# engine_location       0
# wheel_base            0
# length                0
# width                 0
# height                0
# curb_weight           0
# engine_type           0
# num_of_cylinders      0
# engine_size           0
# fuel_system           0
# bore                  4
# stroke                4
# compression_ratio     0
# horsepower            2
# peak_rpm              2
# city_mpg              0
# highway_mpg           0
# price                 4
# dtype: int64

# %% [markdown]
# ### Check if the data contain duplicated values or not **and** if it has ,remove these values

# %%
#not have a duplicated values

Automobile_data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### Replace the missing values in each columns

# %%
Automobile_data = Automobile_data.replace(np.nan, 0.0)

# %%
Automobile_data.isnull().sum().sum()
# Out:
# 0

# %% [markdown]
# ### Save all changes in new excel file called <font color='blue'>cleaned data

# %%
Automobile_data.to_excel('cleaned data.xlsx')

# %% [markdown]
# ### split your data frame based on any condition and store that data frame in df2

# %%
df2 = Automobile_data[Automobile_data['make'] == 'bmw']

# %%
df2
# Out:
#    symboling  normalized_losses make fuel_type aspiration num_of_doors  \
# 10         2              192.0  bmw       gas        std          two
# 11         0              192.0  bmw       gas        std         four
# 12         0              188.0  bmw       gas        std          two
# 13         0              188.0  bmw       gas        std         four
# 14         1                0.0  bmw       gas        std         four
# 15         0                0.0  bmw       gas        std         four
# 16         0                0.0  bmw       gas        std          two
# 17         0                0.0  bmw       gas        std         four
#
#    body_style drive_wheels engine_location  wheel_base  length  width  height  \
# 10      sedan          rwd           front       101.2   176.8   64.8    54.3
# 11      sedan          rwd           front       101.2   176.8   64.8    54.3
# 12      sedan          rwd           front       101.2   176.8   64.8    54.3
# ...

# %% [markdown]
# #

# %% [markdown]
# <h1 align='center'><font color='brown'> Numpy Task

# %% [markdown]
# ### creat any array then sort, display the size....

# %%
arr = np.array([[10,5,9,6],[15,23,6,7]])
arr
# Out:
# array([[10,  5,  9,  6],
#        [15, 23,  6,  7]])

# %% [markdown]
# ### Sort this array

# %%
arr.sort()
arr
# Out:
# array([[ 5,  6,  9, 10],
#        [ 6,  7, 15, 23]])

# %% [markdown]
# ### Display the size & length of the array

# %%
arr.size
# Out:
# 8

# %%
arr.shape
# Out:
# (2, 4)

# %%
len(arr)
# Out:
# 2

# %% [markdown]
# ### Make this array as an array one dimensional

# %%
arr = arr.flatten()

# %%
arr
# Out:
# array([ 5,  6,  9, 10,  6,  7, 15, 23])

# %%
arr.ndim
# Out:
# 1

# %% [markdown]
# ### make an array using random function with size (2,3) & with integer values
# >**hint**: use seed function to make numbers not change

# %%
np.random.seed(0)
arr2 = np.random.randint(6, size = (2,3))
arr2
# Out:
# array([[4, 5, 0],
#        [3, 3, 3]])

# %% [markdown]
# ### Transpose this array

# %%
arr2.T
# Out:
# array([[4, 3],
#        [5, 3],
#        [0, 3]])

# %%
ff = pd.Series(['15s','12',8])
ff
# Out:
# 0    15s
# 1     12
# 2      8
# dtype: object

# %%
pd.to_numeric(ff, errors='coerce')
# Out:
# 0     NaN
# 1    12.0
# 2     8.0
# dtype: float64
